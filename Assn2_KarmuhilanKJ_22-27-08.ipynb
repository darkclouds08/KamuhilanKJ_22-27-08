# %% [markdown]
# #### Karmuhilan K J
# #### 22-27-08
# #### Assignment 2
# #### Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Read the housingdata.csv file into pandas DataFrame and display first six rows of the
# DataFrame

# %%
df = pd.read_csv("housingdata.csv")
df.head(6)
# Out:
#            PID        STATE      PRICE NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0           MP     321654            3        1  1000
# 1  100002000.0  MAHARASHTRA      21325            3      1.5    --
# 2  100003000.0           AP    2541654          NaN        1   850
# 3  100004000.0           TN     321321            1      NaN   700
# 4          NaN           TN  589465645            3        2  1600
# 5  100006000.0           TN   65465466          NaN        1   800

# %% [markdown]
# Display the column names and row index in separate cells.

# %%
df.columns
# Out:
# Index(['PID', 'STATE', 'PRICE', 'NUM_BEDROOMS', 'NUM_BATH', 'SQ_FT'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %% [markdown]
# a) How many numbers of “STATE” exist in the dataset.
#
# b) How many unique states exist in the dataset

# %%
print(f'No. of state values is {df.shape[0]}')
# Out:
# No. of state values is 9

# %%
len(df['STATE'].unique())
# Out:
# 6

# %% [markdown]
# Retrieve the list of all NaN/Null/Empty cells in the form of Boolean list

# %%
df
# Out:
#            PID        STATE      PRICE NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0           MP     321654            3        1  1000
# 1  100002000.0  MAHARASHTRA      21325            3      1.5    --
# 2  100003000.0           AP    2541654          NaN        1   850
# 3  100004000.0           TN     321321            1      NaN   700
# 4          NaN           TN  589465645            3        2  1600
# 5  100006000.0           TN   65465466          NaN        1   800
# 6  100007000.0        ASSAM    3222321            2   HURLEY   950
# 7  100008000.0           HP      23131            1        1   NaN
# 8  100009000.0           HP      21212           na        2  1800

# %%
missing_values = ['na','HURLEY','--']
df.replace(missing_values,np.NaN, inplace= True)
df
# Out:
#            PID        STATE      PRICE NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0           MP     321654            3        1  1000
# 1  100002000.0  MAHARASHTRA      21325            3      1.5   NaN
# 2  100003000.0           AP    2541654          NaN        1   850
# 3  100004000.0           TN     321321            1      NaN   700
# 4          NaN           TN  589465645            3        2  1600
# 5  100006000.0           TN   65465466          NaN        1   800
# 6  100007000.0        ASSAM    3222321            2      NaN   950
# 7  100008000.0           HP      23131            1        1   NaN
# 8  100009000.0           HP      21212          NaN        2  1800

# %%
df.notnull()
# Out:
#      PID  STATE  PRICE  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0   True   True   True          True      True   True
# 1   True   True   True          True      True  False
# 2   True   True   True         False      True   True
# 3   True   True   True          True     False   True
# 4  False   True   True          True      True   True
# 5   True   True   True         False      True   True
# 6   True   True   True          True     False   True
# 7   True   True   True          True      True  False
# 8   True   True   True         False      True   True

# %% [markdown]
# Drop all rows with N/A,NA,na values in Num_Bedrooms

# %%
df.dropna(subset= ["NUM_BEDROOMS"],inplace= True)

# %%
df
# Out:
#            PID        STATE      PRICE NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0           MP     321654            3        1  1000
# 1  100002000.0  MAHARASHTRA      21325            3      1.5   NaN
# 3  100004000.0           TN     321321            1      NaN   700
# 4          NaN           TN  589465645            3        2  1600
# 6  100007000.0        ASSAM    3222321            2      NaN   950
# 7  100008000.0           HP      23131            1        1   NaN

# %% [markdown]
# Replace the NaN and String entries in Num_Bath with previous entry

# %%
df["NUM_BATH"].ffill(inplace= True)

# %%
df
# Out:
#            PID        STATE      PRICE NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0           MP     321654            3        1  1000
# 1  100002000.0  MAHARASHTRA      21325            3      1.5   NaN
# 3  100004000.0           TN     321321            1      1.5   700
# 4          NaN           TN  589465645            3        2  1600
# 6  100007000.0        ASSAM    3222321            2        2   950
# 7  100008000.0           HP      23131            1        1   NaN

# %% [markdown]
# Replace the empty values in “SQ_FT” with the mean of the all entries.

# %%
temp = df['SQ_FT'].dropna()
temp = temp.astype(int,)
df['SQ_FT'].fillna(value = temp.mean(), inplace = True)
df
# Out:
#            PID        STATE      PRICE NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0           MP     321654            3        1    1000
# 1  100002000.0  MAHARASHTRA      21325            3      1.5  1062.5
# 3  100004000.0           TN     321321            1      1.5     700
# 4          NaN           TN  589465645            3        2    1600
# 6  100007000.0        ASSAM    3222321            2        2     950
# 7  100008000.0           HP      23131            1        1  1062.5

# %% [markdown]
# What is the sum of SQ_FT of all entries in the dataset

# %%
df['SQ_FT'] = df['SQ_FT'].astype(float)
df['SQ_FT'].sum()
# Out:
# 6375.0

# %% [markdown]
# Add a new column “NUM_STORE” and with all the values as 1 for all rows

# %%
df['NUM_STORE'] = 1
df
# Out:
#            PID        STATE      PRICE NUM_BEDROOMS NUM_BATH   SQ_FT  \
# 0  100001000.0           MP     321654            3        1  1000.0
# 1  100002000.0  MAHARASHTRA      21325            3      1.5  1062.5
# 3  100004000.0           TN     321321            1      1.5   700.0
# 4          NaN           TN  589465645            3        2  1600.0
# 6  100007000.0        ASSAM    3222321            2        2   950.0
# 7  100008000.0           HP      23131            1        1  1062.5
#
#    NUM_STORE
# 0          1
# 1          1
# 3          1
# 4          1
# 6          1
# 7          1

# %%
df.reset_index(inplace= True)
df
# Out:
#    index          PID        STATE      PRICE NUM_BEDROOMS NUM_BATH   SQ_FT  \
# 0      0  100001000.0           MP     321654            3        1  1000.0
# 1      1  100002000.0  MAHARASHTRA      21325            3      1.5  1062.5
# 2      3  100004000.0           TN     321321            1      1.5   700.0
# 3      4          NaN           TN  589465645            3        2  1600.0
# 4      6  100007000.0        ASSAM    3222321            2        2   950.0
# 5      7  100008000.0           HP      23131            1        1  1062.5
#
#    NUM_STORE
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# 5          1

# %% [markdown]
# Create a DataFrame containing all entries of TN state only

# %%
tndf = df[df['STATE'] == 'TN']
tndf
# Out:
#    index          PID STATE      PRICE NUM_BEDROOMS NUM_BATH   SQ_FT  \
# 2      3  100004000.0    TN     321321            1      1.5   700.0
# 3      4          NaN    TN  589465645            3        2  1600.0
#
#    NUM_STORE
# 2          1
# 3          1

# %% [markdown]
# Create a DataFrame having SQ_FT area greater than 1000 and display the DataFrame

# %%
bigdf = df[df['SQ_FT'] > 1000]
bigdf
# Out:
#    index          PID        STATE      PRICE NUM_BEDROOMS NUM_BATH   SQ_FT  \
# 1      1  100002000.0  MAHARASHTRA      21325            3      1.5  1062.5
# 3      4          NaN           TN  589465645            3        2  1600.0
# 5      7  100008000.0           HP      23131            1        1  1062.5
#
#    NUM_STORE
# 1          1
# 3          1
# 5          1

# %%
df.drop('index',axis = 1, inplace= True)
df
# Out:
#            PID        STATE      PRICE NUM_BEDROOMS NUM_BATH   SQ_FT  \
# 0  100001000.0           MP     321654            3        1  1000.0
# 1  100002000.0  MAHARASHTRA      21325            3      1.5  1062.5
# 2  100004000.0           TN     321321            1      1.5   700.0
# 3          NaN           TN  589465645            3        2  1600.0
# 4  100007000.0        ASSAM    3222321            2        2   950.0
# 5  100008000.0           HP      23131            1        1  1062.5
#
#    NUM_STORE
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# 5          1

# %% [markdown]
# Create a DataFrame having only first Three columns and First Three rows

# %%
first3df = df.iloc[:3,:3]
first3df
# Out:
#            PID        STATE   PRICE
# 0  100001000.0           MP  321654
# 1  100002000.0  MAHARASHTRA   21325
# 2  100004000.0           TN  321321

# %% [markdown]
# Display the state having highest average price per square foot of housing area.

# %%
res = df.groupby('STATE').sum()
res['avg_pps'] = res['PRICE']/res['SQ_FT']
res.sort_values('avg_pps',inplace= True)
print(res.index[-1])
# Out:
# TN
